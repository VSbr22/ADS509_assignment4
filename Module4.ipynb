# %% [markdown]
# ## Naive Bayes on Political Text
#
# In this notebook we use Naive Bayes to explore and classify political data. See the `README.md` for full details.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sqlite3
import string
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')
import random
import numpy as np
from collections import Counter, defaultdict
from nltk.corpus import stopwords
from string import punctuation
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
convention_db = sqlite3.connect("/content/drive/MyDrive/ColabNotebooks/Assignment 4 datasets/2020_Conventions.db")
cur = convention_db.cursor()

# %%
# Execute a query to list all tables in the database
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch all table names from results
tables = cur.fetchall()

# Print the table names
if tables:
    for table in tables:
        print(table[0])
else:
    print("No tables found in the database.")
# Out:
# conventions

# %%
# Execute a query to list all tables in the database
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch all table names from the result set
tables = cur.fetchall()

# Print the table names
for table in tables:
    print(table[0])
# Out:
# conventions

# %%
# Execute a query to fetch table schema
cur.execute("PRAGMA table_info(conventions)")

# Fetch and print the schema information
schema_info = cur.fetchall()
for column in schema_info:
    print(column)
# Out:
# (0, 'party', 'TEXT', 0, None, 0)
# (1, 'night', 'INTEGER', 0, None, 0)
# (2, 'speaker', 'TEXT', 0, None, 0)
# (3, 'speaker_count', 'INTEGER', 0, None, 0)
# (4, 'time', 'TEXT', 0, None, 0)
# (5, 'text', 'TEXT', 0, None, 0)
# (6, 'text_len', 'TEXT', 0, None, 0)
# (7, 'file', 'TEXT', 0, None, 0)

# %%
# Execute a query to retrieve a few rows from the table
cur.execute("SELECT * FROM conventions LIMIT 5")

# Fetch and print the rows
rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# ('Democratic', 4, 'Unknown', 1, '00:00', 'Skip to content The Company Careers Press Freelancers Blog × Services Transcription Captions Foreign Subtitles Translation Freelancers About Contact Login « Return to Transcript Library home  Transcript Categories  All Transcripts 2020 Election Transcripts Classic Speech Transcripts Congressional Testimony & Hearing Transcripts Debate Transcripts Donald Trump Transcripts Entertainment Transcripts Financial Transcripts Interview Transcripts Political Transcripts Press Conference Transcripts Speech Transcripts Sports Transcripts Technology Transcripts Aug 21, 2020 2020 Democratic National Convention (DNC) Night 4 Transcript Rev  ›  Blog  ›  Transcripts  › 2020 Election Transcripts  ›  2020 Democratic National Convention (DNC) Night 4 Transcript Night 4 of the 2020 Democratic National Convention (DNC) on August 20. Read the full transcript of the event here. Transcribe Your Own Content  Try Rev for free  and save time transcribing, captioning, and subtitling.', '127', 'www_rev_com_blog_transcripts2020-democratic-national-convention-dnc-night-4-transcript.txt')
# ('Democratic', 4, 'Speaker 1', 1, '00:33', 'I’m here by calling the full session of the 48th Quadrennial National Convention of the Democratic Party to order. Welcome all to our final session of this historic and memorable convention. We’ve called the 48th Quadrennial Democratic National Convention to order.', '41', 'www_rev_com_blog_transcripts2020-democratic-national-convention-dnc-night-4-transcript.txt')
# ('Democratic', 4, 'Speaker 2', 1, '00:59', 'Every four years, we come together to reaffirm our democracy. This year, we’ve come to save it.', '17', 'www_rev_com_blog_transcripts2020-democratic-national-convention-dnc-night-4-transcript.txt')
# ('Democratic', 4, 'Kerry Washington', 1, '01:07', 'We fight for a more perfect union because we are fighting for the soul of this country and for our lives. And right now that fight is real.', '28', 'www_rev_com_blog_transcripts2020-democratic-national-convention-dnc-night-4-transcript.txt')
# ('Democratic', 4, 'Bernie Sanders', 1, '01:18', 'We must come together to defeat Donald Trump, and elect Joe Biden and Kamala Harris as our next President and Vice President.', '22', 'www_rev_com_blog_transcripts2020-democratic-national-convention-dnc-night-4-transcript.txt')

# %% [markdown]
# ### Part 1: Exploratory Naive Bayes
#
# We'll first build a NB model on the convention data itself, as a way to understand what words distinguish between the two parties. This is analogous to what we did in the "Comparing Groups" class work. First, pull in the text
# for each party and prepare it for use in Naive Bayes.

# %%
stop_words = set(stopwords.words('english'))

def remove_punctuation(text):
    # Remove punctuation
    return "".join([ch for ch in text if ch not in string.punctuation])

# Function to preprocess
def preprocess_text(text):
    # Convert text to lowercase
    unwanted_patterns = [
        r'skip to content\.',
        r'The company.*?today\.',
    ]
    text = text.lower()
    text_without_urls = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.MULTILINE)
    text = remove_punctuation(text)
    # Tokenize the text
    tokens = text.split()
    # Join tokens back into a string
    processed_text = ' '.join(tokens)
    return processed_text

# Execute a query to retrieve data from the convention table
cur.execute("SELECT text, party FROM conventions")
rows = cur.fetchall()

# Fill convention_data list with processed data
convention_data = []
for row in rows:
    text = preprocess_text(row[0])
    party = row[1]
    convention_data.append((text, party))  # Append party and processed text as a tuple

# %% [markdown]
# Let's look at some random entries and see if they look right.

# %%
random.choices(convention_data,k=10)
# Out:
# [('what a beautiful story okay now let’s talk about another important issue the climate crisis this is an issue that has been on joe biden’s mind for decades in 1986 while working as a senator joe biden introduced one of the first climate bills in congress and he’s continued to listen to and work with climate advocates and activists putting forward a plan to address climate change and create a clean energy economy',
#   'Democratic'),
#  ('thank you senator as the 46th mayor of a city that’s more than ready for our 46th president i’m proud to cast minnesota’s 31 votes for bernie sanders and 60 votes for our next us president joe biden',
#   'Democratic'),
#  ('joe biden is a decent man with a long history of public service to america',
#   'Democratic'),
#  ('california', 'Democratic'),
#  ('they hoped to raise 15 billion one person who did not want to talk about it joe biden',
#   'Republican'),
#  ('my dad was a healthy 65 year old his only preexisting condition was trusting donald trump and for that he paid with his life i am not alone once i told my story a lot of people reached out to me to share theirs they asked me to help them keep their communities safe especially communities of color which have been disproportionately affected they asked me a normal person to help because donald trump won’t the coronavirus has made it clear that there are two americas the america that donald trump lives in and the america that my father died in',
#   'Democratic'),
#  ('so i just want to say that i am committed to take care of my family my students and all my staff at my school i will do whatever it takes to ensure that we are all ready to go back to school safe and healthy i know that i am optimistic to move forward with our life and joe biden will be the one to take us there i just want to say for everyone to please remember to wash their hands and wear their mask because we’re all in this together',
#   'Democratic'),
#  ('i had tried holding it all together but without reliable childcare working was nearly impossible and when i told aunt bee i was going to quit my job i thought my heart would break and then she said the words that changed my life “i can’t get there tomorrow but i’ll come on thursday” and she arrived with seven suitcases and a pekinese named buddy and stayed for 16 years i get to be here tonight because of my aunt bee i learned a fundamental truth nobody makes it on their own and yet here we are two generations of working parents later and if you have a baby and don’t have an aunt bee you’re on your own here’s why that is wrong we build infrastructure like roads and bridges and communication systems so that people can work that infrastructure helps us all because it keeps our economy going',
#   'Democratic'),
#  ('two men who represent these two wings of the democratic party coming together',
#   'Democratic'),
#  ('we started fighting for right to try which basically says if you have a terminal illness and there is a drug that exists and you don’t qualify for the clinical trial there is no other way to receive it this is a unique pathway that allows you to have access you made us a promise back in indiana that you would do whatever it took to help jordan and we’re so grateful that you joined us on this journey and stuck it out until it became law so that other people could access treatments',
#   'Republican')]

# %%
tokens = [w for t, p in convention_data for w in t.split()]

# %% [markdown]
# If that looks good, we now need to make our function to turn these into features. In my solution, I wanted to keep the number of features reasonable, so I only used words that occur at least `word_cutoff` times. Here's the code to test that if you want it.

# %%
word_cutoff = 5
tokens = [w for t, p in convention_data for w in t.split()]

word_dist = nltk.FreqDist(tokens)

feature_words = set()

for word, count in word_dist.items() :
    if count > word_cutoff :
        feature_words.add(word)

print(f"With a word cutoff of {word_cutoff}, we have {len(feature_words)} as features in the model.")
# Out:
# With a word cutoff of 5, we have 2514 as features in the model.

# %%
def conv_features(text, feature_words):
    processed_text = preprocess_text(text)
    result_dict = {}
    for word in feature_words:
        if word.lower() in processed_text.lower().split():
            result_dict[word] = True
            print(f"Word: {repr(word)} in feature_words is in processed_text.")
    return result_dict

# %%
assert(len(feature_words)>0)

# %%
conv_features("donald is the president", feature_words)
assert {'donald': True,'president': True}
# Out:
# Word: 'the' in feature_words is in processed_text.
# Word: 'donald' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'president' in feature_words is in processed_text.

# %%
conv_features("people are american in america", feature_words)
assert {'america': True,'american': True,"people": True}
# Out:
# Word: 'in' in feature_words is in processed_text.
# Word: 'america' in feature_words is in processed_text.
# Word: 'american' in feature_words is in processed_text.
# Word: 'people' in feature_words is in processed_text.
# Word: 'are' in feature_words is in processed_text.

# %% [markdown]
# Now we'll build our feature set. Out of curiosity I did a train/test split to see how accurate the classifier was, but we don't strictly need to since this analysis is exploratory.

# %%
featuresets = [(conv_features(text,feature_words), party) for (text, party) in convention_data]
pass
# Out:
# Streaming output truncated to the last 5000 lines.
# Word: 'millions' in feature_words is in processed_text.
# Word: 'actually' in feature_words is in processed_text.
# Word: 'making' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'conversation' in feature_words is in processed_text.
# Word: 'people' in feature_words is in processed_text.
# Word: 'next' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'biden' in feature_words is in processed_text.
# Word: 'that’s' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'jobs' in feature_words is in processed_text.
# Word: 'comes' in feature_words is in processed_text.
# Word: 'million' in feature_words is in processed_text.
# Word: 'harris' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: '5' in feature_words is in processed_text.
# Word: 'have' in feature_words is in processed_text.
# Word: 'me' in feature_words is in processed_text.
# Word: 'union' in feature_words is in processed_text.
# Word: 'can' in feature_words is in processed_text.
# Word: 'back' in feature_words is in processed_text.
# Word: 'only' in feature_words is in processed_text.
# Word: 'childcare' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'let' in feature_words is in processed_text.
# Word: 'bringing' in feature_words is in processed_text.
# Word: 'kamala' in feature_words is in processed_text.
# Word: 'about' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'clean' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'what' in feature_words is in processed_text.
# Word: 'how' in feature_words is in processed_text.
# Word: 'all' in feature_words is in processed_text.
# Word: 'building' in feature_words is in processed_text.
# Word: 'lost' in feature_words is in processed_text.
# Word: 'you’re' in feature_words is in processed_text.
# Word: 'my' in feature_words is in processed_text.
# Word: 'afford' in feature_words is in processed_text.
# Word: 'president' in feature_words is in processed_text.
# Word: 'said' in feature_words is in processed_text.
# Word: 'by' in feature_words is in processed_text.
# Word: 'stronger' in feature_words is in processed_text.
# Word: 'creating' in feature_words is in processed_text.
# Word: 'one' in feature_words is in processed_text.
# Word: 'upon' in feature_words is in processed_text.
# Word: 'supply' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'there’s' in feature_words is in processed_text.
# Word: 'business' in feature_words is in processed_text.
# Word: 'story' in feature_words is in processed_text.
# Word: 'every' in feature_words is in processed_text.
# Word: 'behind' in feature_words is in processed_text.
# Word: 'economic' in feature_words is in processed_text.
# Word: 'pandemic' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'coronavirus' in feature_words is in processed_text.
# Word: 'country' in feature_words is in processed_text.
# Word: 'businesses' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'are' in feature_words is in processed_text.
# Word: 'small' in feature_words is in processed_text.
# Word: 'around' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'there’s' in feature_words is in processed_text.
# Word: 'business' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'every' in feature_words is in processed_text.
# Word: 'behind' in feature_words is in processed_text.
# Word: 'family' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'people' in feature_words is in processed_text.
# Word: 'clearly' in feature_words is in processed_text.
# Word: 'are' in feature_words is in processed_text.
# Word: 'pain' in feature_words is in processed_text.
# Word: 'right' in feature_words is in processed_text.
# Word: 'lot' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'farm' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'there’s' in feature_words is in processed_text.
# Word: 'stay' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'whole' in feature_words is in processed_text.
# Word: 'every' in feature_words is in processed_text.
# Word: 'fight' in feature_words is in processed_text.
# Word: 'work' in feature_words is in processed_text.
# Word: 'there’s' in feature_words is in processed_text.
# Word: 'hard' in feature_words is in processed_text.
# Word: 'there’s' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'businesses' in feature_words is in processed_text.
# Word: '20' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: '30' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'lose' in feature_words is in processed_text.
# Word: 'are' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'small' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'business' in feature_words is in processed_text.
# Word: 'story' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'ohio' in feature_words is in processed_text.
# Word: 'county' in feature_words is in processed_text.
# Word: 'family' in feature_words is in processed_text.
# Word: 'given' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'employees' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'hit' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'have' in feature_words is in processed_text.
# Word: 'on' in feature_words is in processed_text.
# Word: 'day' in feature_words is in processed_text.
# Word: '10' in feature_words is in processed_text.
# Word: 'lot' in feature_words is in processed_text.
# Word: 'covid19' in feature_words is in processed_text.
# Word: '12' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'remember' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'scared' in feature_words is in processed_text.
# Word: 'uncertain' in feature_words is in processed_text.
# Word: 'being' in feature_words is in processed_text.
# Word: 'come' in feature_words is in processed_text.
# Word: 'work' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'enough' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'look' in feature_words is in processed_text.
# Word: 'if' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'ran' in feature_words is in processed_text.
# Word: 'week' in feature_words is in processed_text.
# Word: 'we’re' in feature_words is in processed_text.
# Word: 'get' in feature_words is in processed_text.
# Word: 'don’t' in feature_words is in processed_text.
# Word: 'at' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'shut' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'another' in feature_words is in processed_text.
# Word: 'down' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'have' in feature_words is in processed_text.
# Word: 'last' in feature_words is in processed_text.
# Word: 'out' in feature_words is in processed_text.
# Word: 'shutdown' in feature_words is in processed_text.
# Word: 'because' in feature_words is in processed_text.
# Word: 'got' in feature_words is in processed_text.
# Word: 'plan' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'big' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'equipment' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'future' in feature_words is in processed_text.
# Word: 'can’t' in feature_words is in processed_text.
# Word: 'make' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'if' in feature_words is in processed_text.
# Word: 'know' in feature_words is in processed_text.
# Word: 'don’t' in feature_words is in processed_text.
# Word: 'even' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'can' in feature_words is in processed_text.
# Word: 'cover' in feature_words is in processed_text.
# Word: 'isn’t' in feature_words is in processed_text.
# Word: 'well' in feature_words is in processed_text.
# Word: 'it’s' in feature_words is in processed_text.
# Word: 'always' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'manufacturing' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'forgotten' in feature_words is in processed_text.
# Word: 'companies' in feature_words is in processed_text.
# Word: 'market' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'kind' in feature_words is in processed_text.
# Word: 'about' in feature_words is in processed_text.
# Word: 'behind' in feature_words is in processed_text.
# Word: 'right' in feature_words is in processed_text.
# Word: 'lot' in feature_words is in processed_text.
# Word: 'you’re' in feature_words is in processed_text.
# Word: 'leaves' in feature_words is in processed_text.
# Word: 'president' in feature_words is in processed_text.
# Word: 'sort' in feature_words is in processed_text.
# Word: 'small' in feature_words is in processed_text.
# Word: 'then' in feature_words is in processed_text.
# Word: 'two' in feature_words is in processed_text.
# Word: 'seems' in feature_words is in processed_text.
# Word: 'forward' in feature_words is in processed_text.
# Word: 'use' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'get' in feature_words is in processed_text.
# Word: 'help' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'like' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'back' in feature_words is in processed_text.
# Word: 'just' in feature_words is in processed_text.
# Word: 'right' in feature_words is in processed_text.
# Word: 'little' in feature_words is in processed_text.
# Word: 'could' in feature_words is in processed_text.
# Word: 'one' in feature_words is in processed_text.
# Word: 'step' in feature_words is in processed_text.
# Word: 'then' in feature_words is in processed_text.
# Word: 'who' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'hit' in feature_words is in processed_text.
# Word: 'story' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'store' in feature_words is in processed_text.
# Word: 'green' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'covid' in feature_words is in processed_text.
# Word: 'just' in feature_words is in processed_text.
# Word: 'started' in feature_words is in processed_text.
# Word: 'then' in feature_words is in processed_text.
# Word: 'who' in feature_words is in processed_text.
# Word: 'myself' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: '2019' in feature_words is in processed_text.
# Word: 'an' in feature_words is in processed_text.
# Word: 'they' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'alone' in feature_words is in processed_text.
# Word: 'i’m' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'more' in feature_words is in processed_text.
# Word: 'been' in feature_words is in processed_text.
# Word: 'kid' in feature_words is in processed_text.
# Word: 'american' in feature_words is in processed_text.
# Word: 'get' in feature_words is in processed_text.
# Word: 'love' in feature_words is in processed_text.
# Word: 'businesses' in feature_words is in processed_text.
# Word: 'gone' in feature_words is in processed_text.
# Word: 'open' in feature_words is in processed_text.
# Word: 'reached' in feature_words is in processed_text.
# Word: 'business' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'employees' in feature_words is in processed_text.
# Word: 'no' in feature_words is in processed_text.
# Word: 'like' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'here’s' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'under' in feature_words is in processed_text.
# Word: 'save' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'feel' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'female' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'say' in feature_words is in processed_text.
# Word: 'its' in feature_words is in processed_text.
# Word: 'million' in feature_words is in processed_text.
# Word: 'anything' in feature_words is in processed_text.
# Word: 'bigger' in feature_words is in processed_text.
# Word: 'hard' in feature_words is in processed_text.
# Word: 'money' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'did' in feature_words is in processed_text.
# Word: 'has' in feature_words is in processed_text.
# Word: 'can' in feature_words is in processed_text.
# Word: 'mine' in feature_words is in processed_text.
# Word: 'since' in feature_words is in processed_text.
# Word: 'store' in feature_words is in processed_text.
# Word: 'being' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'covid' in feature_words is in processed_text.
# Word: 'struggle' in feature_words is in processed_text.
# Word: 'out' in feature_words is in processed_text.
# Word: 'african' in feature_words is in processed_text.
# Word: 'just' in feature_words is in processed_text.
# Word: 'really' in feature_words is in processed_text.
# Word: 'trump' in feature_words is in processed_text.
# Word: 'worked' in feature_words is in processed_text.
# Word: 'how' in feature_words is in processed_text.
# Word: 'had' in feature_words is in processed_text.
# Word: 'lot' in feature_words is in processed_text.
# Word: 'my' in feature_words is in processed_text.
# Word: 'cutting' in feature_words is in processed_text.
# Word: 'president' in feature_words is in processed_text.
# Word: 'they’re' in feature_words is in processed_text.
# Word: 'one' in feature_words is in processed_text.
# Word: 'small' in feature_words is in processed_text.
# Word: 'two' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'restaurants' in feature_words is in processed_text.
# Word: 'open' in feature_words is in processed_text.
# Word: 'story' in feature_words is in processed_text.
# Word: 'still' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'her' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'one' in feature_words is in processed_text.
# Word: 'closed' in feature_words is in processed_text.
# Word: 'exciting' in feature_words is in processed_text.
# Word: 'begin' in feature_words is in processed_text.
# Word: 'with' in feature_words is in processed_text.
# Word: 'always' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'pretty' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'pandemic' in feature_words is in processed_text.
# Word: 'be' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'times' in feature_words is in processed_text.
# Word: 'would' in feature_words is in processed_text.
# Word: 'restaurants' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'global' in feature_words is in processed_text.
# Word: 'here' in feature_words is in processed_text.
# Word: 'get' in feature_words is in processed_text.
# Word: 'waiting' in feature_words is in processed_text.
# Word: 'families' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'actually' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'were' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'hard' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'on' in feature_words is in processed_text.
# Word: 'announced' in feature_words is in processed_text.
# Word: 'it’s' in feature_words is in processed_text.
# Word: 'day' in feature_words is in processed_text.
# Word: 'virus' in feature_words is in processed_text.
# Word: 'shutdown' in feature_words is in processed_text.
# Word: 'really' in feature_words is in processed_text.
# Word: 'outside' in feature_words is in processed_text.
# Word: 'as' in feature_words is in processed_text.
# Word: 'street' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'if' in feature_words is in processed_text.
# Word: 'be' in feature_words is in processed_text.
# Word: 'year' in feature_words is in processed_text.
# Word: 'turn' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'goes' in feature_words is in processed_text.
# Word: 'we’re' in feature_words is in processed_text.
# Word: 'don’t' in feature_words is in processed_text.
# Word: 'see' in feature_words is in processed_text.
# Word: 'usa' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'down' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'soon' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'it’s' in feature_words is in processed_text.
# Word: 'mean' in feature_words is in processed_text.
# Word: 'sad' in feature_words is in processed_text.
# Word: 'just' in feature_words is in processed_text.
# Word: 'really' in feature_words is in processed_text.
# Word: 'you’re' in feature_words is in processed_text.
# Word: 'around' in feature_words is in processed_text.
# Word: 'myself' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'looking' in feature_words is in processed_text.
# Word: 'first' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'don’t' in feature_words is in processed_text.
# Word: 'at' in feature_words is in processed_text.
# Word: 'hundred' in feature_words is in processed_text.
# Word: 'even' in feature_words is in processed_text.
# Word: 'business' in feature_words is in processed_text.
# Word: 'decision' in feature_words is in processed_text.
# Word: 'see' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'people' in feature_words is in processed_text.
# Word: 'next' in feature_words is in processed_text.
# Word: 'call' in feature_words is in processed_text.
# Word: 'point' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'month' in feature_words is in processed_text.
# Word: 'are' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'everybody' in feature_words is in processed_text.
# Word: 'had' in feature_words is in processed_text.
# Word: 'make' in feature_words is in processed_text.
# Word: 'because' in feature_words is in processed_text.
# Word: 'unfortunately' in feature_words is in processed_text.
# Word: 'foreign' in feature_words is in processed_text.
# Word: 'language' in feature_words is in processed_text.
# Word: 'foreign' in feature_words is in processed_text.
# Word: 'language' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'without' in feature_words is in processed_text.
# Word: 'know' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'we’re' in feature_words is in processed_text.
# Word: 'don’t' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'like' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'from' in feature_words is in processed_text.
# Word: 'must' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'feel' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'much' in feature_words is in processed_text.
# Word: 'ask' in feature_words is in processed_text.
# Word: 'right' in feature_words is in processed_text.
# Word: 'you’re' in feature_words is in processed_text.
# Word: 'government' in feature_words is in processed_text.
# Word: 'us' in feature_words is in processed_text.
# Word: 'myself' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'restaurants' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'among' in feature_words is in processed_text.
# Word: 'businesses' in feature_words is in processed_text.
# Word: 'at' in feature_words is in processed_text.
# Word: 'hundred' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'employees' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'successful' in feature_words is in processed_text.
# Word: 'do' in feature_words is in processed_text.
# Word: 'only' in feature_words is in processed_text.
# Word: 'hardest' in feature_words is in processed_text.
# Word: 'are' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'career' in feature_words is in processed_text.
# Word: 'provide' in feature_words is in processed_text.
# Word: 'way' in feature_words is in processed_text.
# Word: 'succeed' in feature_words is in processed_text.
# Word: 'so' in feature_words is in processed_text.
# Word: 'sure' in feature_words is in processed_text.
# Word: 'alive' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'he’s' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'i’m' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'he' in feature_words is in processed_text.
# Word: 'don’t' in feature_words is in processed_text.
# Word: 'business' in feature_words is in processed_text.
# Word: 'story' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'understands' in feature_words is in processed_text.
# Word: 'farmer' in feature_words is in processed_text.
# Word: 'thinks' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'struggling' in feature_words is in processed_text.
# Word: 'about' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'think' in feature_words is in processed_text.
# Word: 'his' in feature_words is in processed_text.
# Word: 'farmers' in feature_words is in processed_text.
# Word: 'president' in feature_words is in processed_text.
# Word: 'generation' in feature_words is in processed_text.
# Word: 'keep' in feature_words is in processed_text.
# Word: 'as' in feature_words is in processed_text.
# Word: 'stuff' in feature_words is in processed_text.
# Word: 'he' in feature_words is in processed_text.
# Word: 'no' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'has' in feature_words is in processed_text.
# Word: 'about' in feature_words is in processed_text.
# Word: 'farm' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'bit' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'me' in feature_words is in processed_text.
# Word: 'about' in feature_words is in processed_text.
# Word: 'tell' in feature_words is in processed_text.
# Word: 'little' in feature_words is in processed_text.
# Word: 'then' in feature_words is in processed_text.
# Word: 'with' in feature_words is in processed_text.
# Word: 'through' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'tariffs' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'advantage' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'here' in feature_words is in processed_text.
# Word: 'been' in feature_words is in processed_text.
# Word: 'everything' in feature_words is in processed_text.
# Word: 'battle' in feature_words is in processed_text.
# Word: 'they’ve' in feature_words is in processed_text.
# Word: 'no' in feature_words is in processed_text.
# Word: 'hit' in feature_words is in processed_text.
# Word: 'part' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'unless' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'language' in feature_words is in processed_text.
# Word: 'we’ve' in feature_words is in processed_text.
# Word: 'that’s' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'kind' in feature_words is in processed_text.
# Word: 'have' in feature_words is in processed_text.
# Word: 'deal' in feature_words is in processed_text.
# Word: 'since' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'covid' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'problem' in feature_words is in processed_text.
# Word: 'day' in feature_words is in processed_text.
# Word: 'their' in feature_words is in processed_text.
# Word: 'just' in feature_words is in processed_text.
# Word: 'does' in feature_words is in processed_text.
# Word: 'china' in feature_words is in processed_text.
# Word: 'what' in feature_words is in processed_text.
# Word: 'getting' in feature_words is in processed_text.
# Word: 'said' in feature_words is in processed_text.
# Word: 'trade' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'something' in feature_words is in processed_text.
# Word: 'voice' in feature_words is in processed_text.
# Word: 'be' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'will' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'clear' in feature_words is in processed_text.
# Word: 'biden' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'have' in feature_words is in processed_text.
# Word: 'believe' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'had' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'us' in feature_words is in processed_text.
# Word: 'with' in feature_words is in processed_text.
# Word: 'an' in feature_words is in processed_text.
# Word: 'average' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'he’s' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'american' in feature_words is in processed_text.
# Word: 'biden' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'understanding' in feature_words is in processed_text.
# Word: 'experiencing' in feature_words is in processed_text.
# Word: 'me' in feature_words is in processed_text.
# Word: 'has' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'think' in feature_words is in processed_text.
# Word: 'what' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'enough' in feature_words is in processed_text.
# Word: 'through' in feature_words is in processed_text.
# Word: 'manage' in feature_words is in processed_text.
# Word: 'pandemic' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'class' in feature_words is in processed_text.
# Word: 'middle' in feature_words is in processed_text.
# Word: 'businesses' in feature_words is in processed_text.
# Word: 'folks' in feature_words is in processed_text.
# Word: 'time' in feature_words is in processed_text.
# Word: 'help' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'it’s' in feature_words is in processed_text.
# Word: 'their' in feature_words is in processed_text.
# Word: 'way' in feature_words is in processed_text.
# Word: 'small' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'confidence' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'he’s' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'biden' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'have' in feature_words is in processed_text.
# Word: 'deal' in feature_words is in processed_text.
# Word: 'real' in feature_words is in processed_text.
# Word: 'lot' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'know' in feature_words is in processed_text.
# Word: 'will' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'at' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'we’ve' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'day' in feature_words is in processed_text.
# Word: 'endure' in feature_words is in processed_text.
# Word: 'lot' in feature_words is in processed_text.
# Word: 'taken' in feature_words is in processed_text.
# Word: 'end' in feature_words is in processed_text.
# Word: 'will' in feature_words is in processed_text.
# Word: 'again' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'rise' in feature_words is in processed_text.
# Word: 'running' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'get' in feature_words is in processed_text.
# Word: 'up' in feature_words is in processed_text.
# Word: 'time' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'down' in feature_words is in processed_text.
# Word: 'every' in feature_words is in processed_text.
# Word: 'keep' in feature_words is in processed_text.
# Word: 'got' in feature_words is in processed_text.
# Word: 'who' in feature_words is in processed_text.
# Word: 'heard' in feature_words is in processed_text.
# Word: 'from' in feature_words is in processed_text.
# Word: 'people' in feature_words is in processed_text.
# Word: 'we’ve' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'tonight' in feature_words is in processed_text.
# Word: 'make' in feature_words is in processed_text.
# Word: 'idea' in feature_words is in processed_text.
# Word: 'work' in feature_words is in processed_text.
# Word: 'who' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'already' in feature_words is in processed_text.
# Word: 'options' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'heard' in feature_words is in processed_text.
# Word: 'pandemic' in feature_words is in processed_text.
# Word: 'education' in feature_words is in processed_text.
# Word: 'stuck' in feature_words is in processed_text.
# Word: 'america' in feature_words is in processed_text.
# Word: 'safely' in feature_words is in processed_text.
# Word: 'big' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'country' in feature_words is in processed_text.
# Word: 'i’m' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'here' in feature_words is in processed_text.
# Word: 'been' in feature_words is in processed_text.
# Word: 'at' in feature_words is in processed_text.
# Word: 'even' in feature_words is in processed_text.
# Word: 'they’ve' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'which' in feature_words is in processed_text.
# Word: 'no' in feature_words is in processed_text.
# Word: 'see' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'hit' in feature_words is in processed_text.
# Word: 'schools' in feature_words is in processed_text.
# Word: 'line' in feature_words is in processed_text.
# Word: 'from' in feature_words is in processed_text.
# Word: 'people' in feature_words is in processed_text.
# Word: 'after' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'lives' in feature_words is in processed_text.
# Word: 'before' in feature_words is in processed_text.
# Word: 'early' in feature_words is in processed_text.
# Word: 'we’ve' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'another' in feature_words is in processed_text.
# Word: 'put' in feature_words is in processed_text.
# Word: 'center' in feature_words is in processed_text.
# Word: 'solutions' in feature_words is in processed_text.
# Word: 'hard' in feature_words is in processed_text.
# Word: 'has' in feature_words is in processed_text.
# Word: 'demand' in feature_words is in processed_text.
# Word: 'on' in feature_words is in processed_text.
# Word: 'can' in feature_words is in processed_text.
# Word: 'done' in feature_words is in processed_text.
# Word: 'since' in feature_words is in processed_text.
# Word: 'childcare' in feature_words is in processed_text.
# Word: 'is' in feature_words is in processed_text.
# Word: 'covid' in feature_words is in processed_text.
# Word: 'problems' in feature_words is in processed_text.
# Word: 'are' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'well' in feature_words is in processed_text.
# Word: 'months' in feature_words is in processed_text.
# Word: 'parents' in feature_words is in processed_text.
# Word: 'their' in feature_words is in processed_text.
# Word: 'what' in feature_words is in processed_text.
# Word: 'way' in feature_words is in processed_text.
# Word: 'tonight' in feature_words is in processed_text.
# Word: 'keep' in feature_words is in processed_text.
# Word: 'taken' in feature_words is in processed_text.
# Word: 'covid19' in feature_words is in processed_text.
# Word: 'make' in feature_words is in processed_text.
# Word: 'one' in feature_words is in processed_text.
# Word: 'reopen' in feature_words is in processed_text.
# Word: 'find' in feature_words is in processed_text.
# Word: 'closed' in feature_words is in processed_text.
# Word: 'work' in feature_words is in processed_text.
# Word: 'energy' in feature_words is in processed_text.
# Word: 'truth' in feature_words is in processed_text.
# Word: 'else' in feature_words is in processed_text.
# Word: 'who' in feature_words is in processed_text.
# Word: 'plan' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'create' in feature_words is in processed_text.
# Word: 'economic' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'manufacturing' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'these' in feature_words is in processed_text.
# Word: 'build' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'economy' in feature_words is in processed_text.
# Word: 'give' in feature_words is in processed_text.
# Word: 'been' in feature_words is in processed_text.
# Word: 'investing' in feature_words is in processed_text.
# Word: 'good' in feature_words is in processed_text.
# Word: 'love' in feature_words is in processed_text.
# Word: 'what’s' in feature_words is in processed_text.
# Word: 'families' in feature_words is in processed_text.
# Word: 'them' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'bring' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'increase' in feature_words is in processed_text.
# Word: 'biden' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'plans' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'jobs' in feature_words is in processed_text.
# Word: 'laws' in feature_words is in processed_text.
# Word: 'cancel' in feature_words is in processed_text.
# Word: 'security' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'broken' in feature_words is in processed_text.
# Word: 'reflect' in feature_words is in processed_text.
# Word: 'union' in feature_words is in processed_text.
# Word: 'has' in feature_words is in processed_text.
# Word: 'system' in feature_words is in processed_text.
# Word: 'can' in feature_words is in processed_text.
# Word: 'debt' in feature_words is in processed_text.
# Word: 'student' in feature_words is in processed_text.
# Word: 'back' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'billions' in feature_words is in processed_text.
# Word: 'clean' in feature_words is in processed_text.
# Word: 'new' in feature_words is in processed_text.
# Word: 'thriving' in feature_words is in processed_text.
# Word: 'some' in feature_words is in processed_text.
# Word: 'really' in feature_words is in processed_text.
# Word: 'face' in feature_words is in processed_text.
# Word: 'by' in feature_words is in processed_text.
# Word: 'social' in feature_words is in processed_text.
# Word: 'instead' in feature_words is in processed_text.
# Word: 'make' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'everyone' in feature_words is in processed_text.
# Word: 'then' in feature_words is in processed_text.
# Word: 'plan' in feature_words is in processed_text.
# Word: 'called' in feature_words is in processed_text.
# Word: 'heart' in feature_words is in processed_text.
# Word: 'accountable' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'teacher' in feature_words is in processed_text.
# Word: 'fighting' in feature_words is in processed_text.
# Word: 'be' in feature_words is in processed_text.
# Word: 'first' in feature_words is in processed_text.
# Word: 'check' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'big' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'build' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'washington' in feature_words is in processed_text.
# Word: 'better' in feature_words is in processed_text.
# Word: 'racial' in feature_words is in processed_text.
# Word: 'thought' in feature_words is in processed_text.
# Word: 'joe’s' in feature_words is in processed_text.
# Word: 'up' in feature_words is in processed_text.
# Word: 'world' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'close' in feature_words is in processed_text.
# Word: 'teaching' in feature_words is in processed_text.
# Word: 'loved' in feature_words is in processed_text.
# Word: 'making' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'job' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'that’s' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'plans' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'share' in feature_words is in processed_text.
# Word: 'down' in feature_words is in processed_text.
# Word: 'hard' in feature_words is in processed_text.
# Word: 'growing' in feature_words is in processed_text.
# Word: 'corporations' in feature_words is in processed_text.
# Word: 'texas' in feature_words is in processed_text.
# Word: 'pay' in feature_words is in processed_text.
# Word: 'almost' in feature_words is in processed_text.
# Word: 'oklahoma' in feature_words is in processed_text.
# Word: 'me' in feature_words is in processed_text.
# Word: 'do' in feature_words is in processed_text.
# Word: 'back' in feature_words is in processed_text.
# Word: 'childcare' in feature_words is in processed_text.
# Word: 'let' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'about' in feature_words is in processed_text.
# Word: 'holding' in feature_words is in processed_text.
# Word: 'wanted' in feature_words is in processed_text.
# Word: 'broke' in feature_words is in processed_text.
# Word: 'thing' in feature_words is in processed_text.
# Word: 'their' in feature_words is in processed_text.
# Word: 'tell' in feature_words is in processed_text.
# Word: 'just' in feature_words is in processed_text.
# Word: 'what' in feature_words is in processed_text.
# Word: 'fair' in feature_words is in processed_text.
# Word: 'girl' in feature_words is in processed_text.
# Word: 'started' in feature_words is in processed_text.
# Word: 'little' in feature_words is in processed_text.
# Word: 'had' in feature_words is in processed_text.
# Word: 'most' in feature_words is in processed_text.
# Word: 'could' in feature_words is in processed_text.
# Word: 'fine' in feature_words is in processed_text.
# Word: 'my' in feature_words is in processed_text.
# Word: 'especially' in feature_words is in processed_text.
# Word: 'as' in feature_words is in processed_text.
# Word: 'one' in feature_words is in processed_text.
# Word: 'night' in feature_words is in processed_text.
# Word: 'come' in feature_words is in processed_text.
# Word: 'work' in feature_words is in processed_text.
# Word: 'then' in feature_words is in processed_text.
# Word: 'truth' in feature_words is in processed_text.
# Word: 'with' in feature_words is in processed_text.
# Word: 'going' in feature_words is in processed_text.
# Word: 'quit' in feature_words is in processed_text.
# Word: 'two' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'heart' in feature_words is in processed_text.
# Word: 'so' in feature_words is in processed_text.
# Word: 'own' in feature_words is in processed_text.
# Word: 'an' in feature_words is in processed_text.
# Word: 'without' in feature_words is in processed_text.
# Word: 'if' in feature_words is in processed_text.
# Word: 'working' in feature_words is in processed_text.
# Word: 'be' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'would' in feature_words is in processed_text.
# Word: 'baby' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'build' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'bridges' in feature_words is in processed_text.
# Word: 'economy' in feature_words is in processed_text.
# Word: 'generations' in feature_words is in processed_text.
# ...
# Word: 'important' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'us' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'be' in feature_words is in processed_text.
# Word: 'too' in feature_words is in processed_text.
# Word: 'he' in feature_words is in processed_text.
# Word: 'there' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'me' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'he’ll' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: '2016' in feature_words is in processed_text.
# Word: 'know' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: '“what' in feature_words is in processed_text.
# Word: 'world' in feature_words is in processed_text.
# Word: 'even' in feature_words is in processed_text.
# Word: 'remember' in feature_words is in processed_text.
# Word: 'loved' in feature_words is in processed_text.
# Word: 'when' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'jobs' in feature_words is in processed_text.
# Word: 'office' in feature_words is in processed_text.
# Word: 'ones' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'have' in feature_words is in processed_text.
# Word: 'do' in feature_words is in processed_text.
# Word: 'back' in feature_words is in processed_text.
# Word: 'healthcare' in feature_words is in processed_text.
# Word: 'asked' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'well' in feature_words is in processed_text.
# Word: 'leadership' in feature_words is in processed_text.
# Word: 'trump' in feature_words is in processed_text.
# Word: 'post' in feature_words is in processed_text.
# Word: 'come' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'darkness' in feature_words is in processed_text.
# Word: 'forward' in feature_words is in processed_text.
# Word: 'country' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'light' in feature_words is in processed_text.
# Word: 'together' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'way' in feature_words is in processed_text.
# Word: 'plan' in feature_words is in processed_text.
# Word: 'big' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'now' in feature_words is in processed_text.
# Word: 'good' in feature_words is in processed_text.
# Word: 'love' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'see' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'biden' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'plans' in feature_words is in processed_text.
# Word: 'solutions' in feature_words is in processed_text.
# Word: 'has' in feature_words is in processed_text.
# Word: 'demand' in feature_words is in processed_text.
# Word: 'problems' in feature_words is in processed_text.
# Word: 'some' in feature_words is in processed_text.
# Word: 'really' in feature_words is in processed_text.
# Word: 'way' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'citizens' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'informed' in feature_words is in processed_text.
# Word: 'so' in feature_words is in processed_text.
# Word: 'fix' in feature_words is in processed_text.
# Word: 'own' in feature_words is in processed_text.
# Word: 'an' in feature_words is in processed_text.
# Word: 'vote' in feature_words is in processed_text.
# Word: 'be' in feature_words is in processed_text.
# Word: 'sure' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'embrace' in feature_words is in processed_text.
# Word: 'responsibility' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'alone' in feature_words is in processed_text.
# Word: 'country' in feature_words is in processed_text.
# Word: 'i’m' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'better' in feature_words is in processed_text.
# Word: 'give' in feature_words is in processed_text.
# Word: 'everything' in feature_words is in processed_text.
# Word: 'american' in feature_words is in processed_text.
# Word: 'ability' in feature_words is in processed_text.
# Word: 'even' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'your' in feature_words is in processed_text.
# Word: 'no' in feature_words is in processed_text.
# Word: 'meant' in feature_words is in processed_text.
# Word: 'was' in feature_words is in processed_text.
# Word: 'here’s' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'democracy' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'basic' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'but' in feature_words is in processed_text.
# Word: 'single' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'me' in feature_words is in processed_text.
# Word: 'never' in feature_words is in processed_text.
# Word: 'can' in feature_words is in processed_text.
# Word: 'believe' in feature_words is in processed_text.
# Word: 'also' in feature_words is in processed_text.
# Word: 'requires' in feature_words is in processed_text.
# Word: 'asking' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'not' in feature_words is in processed_text.
# Word: 'thing' in feature_words is in processed_text.
# Word: 'endure' in feature_words is in processed_text.
# Word: 'president' in feature_words is in processed_text.
# Word: 'as' in feature_words is in processed_text.
# Word: 'make' in feature_words is in processed_text.
# Word: 'greetings' in feature_words is in processed_text.
# Word: 'gather' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'heart' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'hatred' in feature_words is in processed_text.
# Word: 'convention' in feature_words is in processed_text.
# Word: 'inequality' in feature_words is in processed_text.
# Word: 'america' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'would' in feature_words is in processed_text.
# Word: 'i' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'better' in feature_words is in processed_text.
# Word: 'greater' in feature_words is in processed_text.
# Word: 'mind' in feature_words is in processed_text.
# Word: 'good' in feature_words is in processed_text.
# Word: 'american' in feature_words is in processed_text.
# Word: 'delegates' in feature_words is in processed_text.
# Word: 'pray' in feature_words is in processed_text.
# Word: 'peace' in feature_words is in processed_text.
# Word: 'highest' in feature_words is in processed_text.
# Word: 'your' in feature_words is in processed_text.
# Word: 'god' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'land' in feature_words is in processed_text.
# Word: 'achieve' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'bring' in feature_words is in processed_text.
# Word: 'and' in feature_words is in processed_text.
# Word: 'biden' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'injustice' in feature_words is in processed_text.
# Word: 'am' in feature_words is in processed_text.
# Word: 'office' in feature_words is in processed_text.
# Word: 'may' in feature_words is in processed_text.
# Word: 'its' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'fairness' in feature_words is in processed_text.
# Word: 'let' in feature_words is in processed_text.
# Word: 'inspire' in feature_words is in processed_text.
# Word: 'light' in feature_words is in processed_text.
# Word: 'vice' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'future' in feature_words is in processed_text.
# Word: 'nation' in feature_words is in processed_text.
# Word: 'best' in feature_words is in processed_text.
# Word: 'common' in feature_words is in processed_text.
# Word: 'face' in feature_words is in processed_text.
# Word: 'most' in feature_words is in processed_text.
# Word: 'president' in feature_words is in processed_text.
# Word: 'fight' in feature_words is in processed_text.
# Word: 'as' in feature_words is in processed_text.
# Word: 'one' in feature_words is in processed_text.
# Word: 'upon' in feature_words is in processed_text.
# Word: 'amen' in feature_words is in processed_text.
# Word: 'name' in feature_words is in processed_text.
# Word: 'joe' in feature_words is in processed_text.
# Word: 'us' in feature_words is in processed_text.
# Word: 'loving' in feature_words is in processed_text.
# Word: 'against' in feature_words is in processed_text.
# Word: 'submit' in feature_words is in processed_text.
# Word: 'for' in feature_words is in processed_text.
# Word: 'chinese' in feature_words is in processed_text.
# Word: 'in' in feature_words is in processed_text.
# Word: 'press' in feature_words is in processed_text.
# Word: 'white' in feature_words is in processed_text.
# Word: 'without' in feature_words is in processed_text.
# Word: 'weekly' in feature_words is in processed_text.
# Word: 'convention' in feature_words is in processed_text.
# Word: '©' in feature_words is in processed_text.
# Word: '222' in feature_words is in processed_text.
# Word: 'careers' in feature_words is in processed_text.
# Word: 'house' in feature_words is in processed_text.
# Word: 'of' in feature_words is in processed_text.
# Word: 'floor' in feature_words is in processed_text.
# Word: 'gov' in feature_words is in processed_text.
# Word: 'related' in feature_words is in processed_text.
# Word: 'ago' in feature_words is in processed_text.
# Word: 'will' in feature_words is in processed_text.
# Word: 'a' in feature_words is in processed_text.
# Word: 'privacy' in feature_words is in processed_text.
# Word: '2' in feature_words is in processed_text.
# Word: 'quote' in feature_words is in processed_text.
# Word: '•' in feature_words is in processed_text.
# Word: 'conference' in feature_words is in processed_text.
# Word: 'get' in feature_words is in processed_text.
# Word: 'complete' in feature_words is in processed_text.
# Word: 'news' in feature_words is in processed_text.
# Word: 'charges' in feature_words is in processed_text.
# Word: 'email' in feature_words is in processed_text.
# Word: 'ca' in feature_words is in processed_text.
# Word: '8883690701' in feature_words is in processed_text.
# Word: '1' in feature_words is in processed_text.
# Word: 'supportrevcom' in feature_words is in processed_text.
# Word: 'business' in feature_words is in processed_text.
# Word: 'it' in feature_words is in processed_text.
# Word: 'your' in feature_words is in processed_text.
# Word: 'browser' in feature_words is in processed_text.
# Word: '16' in feature_words is in processed_text.
# Word: 'stay' in feature_words is in processed_text.
# Word: 'secretary' in feature_words is in processed_text.
# Word: 'iowa' in feature_words is in processed_text.
# Word: 'converter' in feature_words is in processed_text.
# Word: 'that' in feature_words is in processed_text.
# Word: 'hour' in feature_words is in processed_text.
# Word: 'transcript' in feature_words is in processed_text.
# Word: 'translation' in feature_words is in processed_text.
# Word: 'st' in feature_words is in processed_text.
# Word: 'app' in feature_words is in processed_text.
# Word: 'to' in feature_words is in processed_text.
# Word: 'request' in feature_words is in processed_text.
# Word: 'javascript' in feature_words is in processed_text.
# Word: 'inbox' in feature_words is in processed_text.
# Word: 'revcom' in feature_words is in processed_text.
# Word: 'the' in feature_words is in processed_text.
# Word: 'freelancers' in feature_words is in processed_text.
# Word: 'san' in feature_words is in processed_text.
# Word: 'transcription' in feature_words is in processed_text.
# Word: 'kind' in feature_words is in processed_text.
# Word: 'want' in feature_words is in processed_text.
# Word: 'francisco' in feature_words is in processed_text.
# Word: 'we' in feature_words is in processed_text.
# Word: '5' in feature_words is in processed_text.
# Word: 'this' in feature_words is in processed_text.
# Word: 'faq' in feature_words is in processed_text.
# Word: 'works' in feature_words is in processed_text.
# Word: 'kearny' in feature_words is in processed_text.
# Word: 'blog' in feature_words is in processed_text.
# Word: 'do' in feature_words is in processed_text.
# Word: 'hours' in feature_words is in processed_text.
# Word: 'captions' in feature_words is in processed_text.
# Word: '8th' in feature_words is in processed_text.
# Word: 'form' in feature_words is in processed_text.
# Word: 'read' in feature_words is in processed_text.
# Word: 'you' in feature_words is in processed_text.
# Word: 'about' in feature_words is in processed_text.
# Word: 'our' in feature_words is in processed_text.
# Word: 'digest' in feature_words is in processed_text.
# Word: 'company' in feature_words is in processed_text.
# Word: 'terms' in feature_words is in processed_text.
# Word: 'it’s' in feature_words is in processed_text.
# Word: 'subtitles' in feature_words is in processed_text.
# Word: 'please' in feature_words is in processed_text.
# Word: 'contact' in feature_words is in processed_text.
# Word: 'reviews' in feature_words is in processed_text.
# Word: 'updated' in feature_words is in processed_text.
# Word: 'evening' in feature_words is in processed_text.
# Word: 'enable' in feature_words is in processed_text.
# Word: 'what' in feature_words is in processed_text.
# Word: 'how' in feature_words is in processed_text.
# Word: 'mobile' in feature_words is in processed_text.
# Word: 'week’s' in feature_words is in processed_text.
# Word: 'touch' in feature_words is in processed_text.
# Word: 'most' in feature_words is in processed_text.
# Word: 'caption' in feature_words is in processed_text.
# Word: 'other' in feature_words is in processed_text.
# Word: 'until' in feature_words is in processed_text.
# Word: 'transcripts' in feature_words is in processed_text.
# Word: 'certified' in feature_words is in processed_text.
# Word: 'overview' in feature_words is in processed_text.
# Word: 'tomorrow' in feature_words is in processed_text.
# Word: 'stand' in feature_words is in processed_text.
# Word: 'important' in feature_words is in processed_text.
# Word: 'program' in feature_words is in processed_text.
# Word: '94108' in feature_words is in processed_text.
# Word: 'september' in feature_words is in processed_text.
# Word: 'us' in feature_words is in processed_text.
# Word: 'api' in feature_words is in processed_text.
# Word: 'against' in feature_words is in processed_text.

# %%
random.seed(20220507)
random.shuffle(featuresets)

test_size = 500

# %%
test_set, train_set = featuresets[:test_size], featuresets[test_size:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.444

# %%
classifier.show_most_informative_features(25)
# Out:
# Most Informative Features
#                    china = True           Republ : Democr =     25.8 : 1.0
#                    votes = True           Democr : Republ =     23.8 : 1.0
#              enforcement = True           Republ : Democr =     21.5 : 1.0
#                  destroy = True           Republ : Democr =     19.2 : 1.0
#                 freedoms = True           Republ : Democr =     18.2 : 1.0
#                  climate = True           Democr : Republ =     17.8 : 1.0
#                 supports = True           Republ : Democr =     17.1 : 1.0
#                    crime = True           Republ : Democr =     16.1 : 1.0
#                    media = True           Republ : Democr =     14.9 : 1.0
#                  beliefs = True           Republ : Democr =     13.0 : 1.0
#                countries = True           Republ : Democr =     13.0 : 1.0
#                  defense = True           Republ : Democr =     13.0 : 1.0
#                     isis = True           Republ : Democr =     13.0 : 1.0
#                  liberal = True           Republ : Democr =     13.0 : 1.0
#                 religion = True           Republ : Democr =     13.0 : 1.0
#                    trade = True           Republ : Democr =     12.7 : 1.0
#                     flag = True           Republ : Democr =     12.1 : 1.0
#                greatness = True           Republ : Democr =     12.1 : 1.0
#                  abraham = True           Republ : Democr =     11.9 : 1.0
#                   defund = True           Republ : Democr =     11.9 : 1.0
#                     drug = True           Republ : Democr =     10.9 : 1.0
#               department = True           Republ : Democr =     10.9 : 1.0
#                destroyed = True           Republ : Democr =     10.9 : 1.0
#                    enemy = True           Republ : Democr =     10.9 : 1.0
#                amendment = True           Republ : Democr =     10.3 : 1.0

# %% [markdown]
# Write a little prose here about what you see in the classifier. Anything odd or interesting?
#
# ### My Observations
#
# In my observation I would say that many of the words with negative connotations are used more frequently by the Republic party affiliation vs the Democratic party. Democratic party really only out numbers the Republican affiliation when referring to votes or climate change. What I also found very intersting was the the number one feature appears to be China which is also interesting, that would be the most frequent word used by Republican party.

# %% [markdown]
# ## Part 2: Classifying Congressional Tweets
#
# In this part we apply the classifer we just built to a set of tweets by people running for congress
# in 2018. These tweets are stored in the database `congressional_data.db`. That DB is funky, so I'll
# give you the query I used to pull out the tweets. Note that this DB has some big tables and
# is unindexed, so the query takes a minute or two to run on my machine.

# %%
cong_db = sqlite3.connect("/content/drive/MyDrive/ColabNotebooks/Assignment 4 datasets/congressional_data.db")
cong_cur = cong_db.cursor()

# %%
# Execute a query to list all tables in the database
cong_cur.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch all table names from the results
tables = cong_cur.fetchall()

# Print the table names
for table in tables:
    print(table[0])
# Out:
# websites
# candidate_data
# tweets

# %%
cong_cur.execute("PRAGMA table_info(candidate_data)")

# Fetch and print the table schema
table_info = cong_cur.fetchall()
print("Table Schema:")
for column in table_info:
    print(column)
# Out:
# Table Schema:
# (0, 'index', 'INTEGER', 0, None, 0)
# (1, 'student', 'TEXT', 0, None, 0)
# (2, 'state', 'TEXT', 0, None, 0)
# (3, 'district_num', 'TEXT', 0, None, 0)
# (4, 'formatted_dist_num', 'INTEGER', 0, None, 0)
# (5, 'abbrev', 'TEXT', 0, None, 0)
# (6, 'district', 'TEXT', 0, None, 0)
# (7, 'candidate', 'TEXT', 0, None, 0)
# (8, 'party', 'TEXT', 0, None, 0)
# (9, 'website', 'TEXT', 0, None, 0)
# (10, 'twitter_handle', 'TEXT', 0, None, 0)
# (11, 'incumbent', 'TEXT', 0, None, 0)
# (12, 'age', 'REAL', 0, None, 0)
# (13, 'gender', 'TEXT', 0, None, 0)
# (14, 'marital_status', 'TEXT', 0, None, 0)
# (15, 'white_non_hispanic', 'TEXT', 0, None, 0)
# (16, 'hispanic', 'TEXT', 0, None, 0)
# (17, 'black', 'TEXT', 0, None, 0)
# (18, 'partisian_lean_pvi', 'TEXT', 0, None, 0)
# (19, 'opposed', 'TEXT', 0, None, 0)
# (20, 'pct_urban', 'TEXT', 0, None, 0)
# (21, 'income', 'REAL', 0, None, 0)
# (22, 'region', 'TEXT', 0, None, 0)

# %%
# Execute the SQL query
results = cong_cur.execute('''
    SELECT DISTINCT
        cd.candidate,
        cd.party,
        tw.tweet_text
    FROM candidate_data cd
    INNER JOIN tweets tw ON cd.twitter_handle = tw.handle
        AND cd.candidate == tw.candidate
        AND cd.district == tw.district
    WHERE cd.party IN ('Republican', 'Democratic')
        AND tw.tweet_text NOT LIKE '%RT%'
''')

# Store the results in a list
results = list(results)

# %%
for row in results[:10]: #See a limited amount of results, only 10 rows.
    print(row)
# Out:
# ('Mo Brooks', 'Republican', b'"Brooks Joins Alabama Delegation in Voting Against Flawed Funding Bill" http://t.co/3CwjIWYsNq')
# ('Mo Brooks', 'Republican', b'"Brooks: I Do Not Support America Raising, Training, and Arming a \nRebel Army to Fight in Syria\xe2\x80\x99s Civil War" http://t.co/f2QFErMkD4')
# ('Mo Brooks', 'Republican', b'"Brooks: Senate Democrats Allowing President to Give Americans\xe2\x80\x99 Jobs to Illegals" #securetheborder https://t.co/mZtEaX8xS6')
# ('Mo Brooks', 'Republican', b'"NASA on the Square" event this Sat. 11AM \xe2\x80\x93 4PM. Stop by &amp; hear about the incredible work done in #AL05! @DowntownHSV http://t.co/R9zY8WMEpA')
# ('Mo Brooks', 'Republican', b'"Rep. Mo Brooks: NDAA Amnesty Amendment \xe2\x80\x98Betrays Americans\xe2\x80\x99" via @BreitbartNews http://t.co/aflHYdUkuF')
# ('Mo Brooks', 'Republican', b'"The trouble with Socialism is that eventually you run out of other people\'s money." - Margaret Thatcher https://t.co/X97g7wzQwJ')
# ('Mo Brooks', 'Republican', b'"The trouble with socialism is eventually you run out of other people\'s money" \xe2\x80\x93 Thatcher. She\'ll be sorely missed. http://t.co/Z8gBnDQUh8')
# ('Mo Brooks', 'Republican', b'"U.S. Debt Biggest Threat to National Security" #armyaviation http://t.co/4RWjrehH')
# ('Mo Brooks', 'Republican', b'# 1 jobs &amp; economic solution for America is securing U.S. borders to protect jobs &amp; wages for Americans. https://t.co/phURMkQz2R')
# ('Mo Brooks', 'Republican', b"#AL &amp; American hero Jeremiah Denton was laid to rest today - one of the finest patriots I've had the pleasure to meet http://t.co/bSyYrplVu6")

# %%
tweet_data = []

for twitter_name, party, tweet_text in results:
    decoded_tweet_text = tweet_text.decode('utf-8')  # Decode the byte string
    processed_text = preprocess_text(decoded_tweet_text)  # Preprocess the decoded tweet text
    tweet_data.append((twitter_name, party, processed_text))  # Append Twitter name, party, and processed tweet text as a tuple

# Print processed tweet data
for row in tweet_data [:10]:
    twitter_name, party, processed_text = row
    print(f"Twitter Name: {twitter_name}, Party: {party}, Processed Tweet: {processed_text}")
# Out:
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: brooks joins alabama delegation in voting against flawed funding bill httptco3cwjiwysnq
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: brooks i do not support america raising training and arming a rebel army to fight in syria’s civil war httptcof2qfermkd4
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: brooks senate democrats allowing president to give americans’ jobs to illegals securetheborder httpstcomzteax8xs6
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: nasa on the square event this sat 11am – 4pm stop by amp hear about the incredible work done in al05 downtownhsv httptcor9zy8wmepa
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: rep mo brooks ndaa amnesty amendment ‘betrays americans’ via breitbartnews httptcoaflhydukuf
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: the trouble with socialism is that eventually you run out of other peoples money margaret thatcher httpstcox97g7wzqwj
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: the trouble with socialism is eventually you run out of other peoples money – thatcher shell be sorely missed httptcoz8gbndquh8
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: us debt biggest threat to national security armyaviation httptco4rwjrehh
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: 1 jobs amp economic solution for america is securing us borders to protect jobs amp wages for americans httpstcophurmkqz2r
# Twitter Name: Mo Brooks, Party: Republican, Processed Tweet: al amp american hero jeremiah denton was laid to rest today one of the finest patriots ive had the pleasure to meet httptcobsyyrplvu6

# %% [markdown]
# There are a lot of tweets here. Let's take a random sample and see how our classifer does. I'm guessing it won't be too great given the performance on the convention speeches...

# %%
random.seed(20201014)

tweet_data_sample = random.choices(tweet_data,k=10)

# %%
def predict_party(text):
    republican_keywords = ['republican', 'gop', 'conservative', 'right-wing']
    democratic_keywords = ['democrat', 'democratic', 'liberal', 'left-wing']

    # Convert tweet text to lowercase for case-insensitive matching
    lowercased_tweet = processed_text.lower()

    # Check for Republican keywords
    for keyword in republican_keywords:
        if keyword in lowercased_tweet:
            return 'Republican'

    # Check for Democratic keywords
    for keyword in democratic_keywords:
        if keyword in lowercased_tweet:
            return 'Democratic'

    # If no party keywords found, return 'Unknown'
    return 'Unknown'

# %%
for twitter_name, party, processed_text in tweet_data_sample:
    estimated_party = predict_party(processed_text)


    print(f"Twitter Name: {twitter_name}")
    print(f"Actual party is {party} and our classifier says {estimated_party}.")
    print(f"Here's our (cleaned) tweet: {processed_text}")
# Out:
# Twitter Name: Barbara Lee
# Actual party is Democratic and our classifier says Unknown.
# Here's our (cleaned) tweet: the mass shooting in las vegas was a horrific act of violence the victims and their families are in my thoughts and prayers
# Twitter Name: Markwayne Mullin
# Actual party is Republican and our classifier says Unknown.
# Here's our (cleaned) tweet: early morning this traveltuesday leaving ok02 for dc httptcoigknci79e7
# Twitter Name: Joseph Kaufman
# Actual party is Republican and our classifier says Unknown.
# Here's our (cleaned) tweet: the only moderates in iraq amp syria are civilians weve enemies on both sides of the conflict we should not assist either
# Twitter Name: Abigail Spanberger
# Actual party is Democratic and our classifier says Unknown.
# Here's our (cleaned) tweet: rt natsecaction over 200 national security veterans are demanding answers on the release of the confidential national security questionna…
# Twitter Name: Antonio Sabàto Jr
# Actual party is Republican and our classifier says Unknown.
# Here's our (cleaned) tweet: 💯 buildthatwall now httpstcohyb6jcw5ea
# Twitter Name: Brendan Boyle
# Actual party is Democratic and our classifier says Unknown.
# Here's our (cleaned) tweet: i was glad to attend the g20 and assure everyone i could that majority of americans still stand by our traditional allies
# Twitter Name: Kevin Gaither
# Actual party is Democratic and our classifier says Unknown.
# Here's our (cleaned) tweet: cnn everyone wraps themselves in the flag and patriotism to avoid the discussion about racism and injustice kneeling is honoring our troops
# Twitter Name: Ron Wright
# Actual party is Republican and our classifier says Unknown.
# Here's our (cleaned) tweet: i applaud president trumps decision to send the national guard to protect our border congress should support the president on this including fully funding the wall its time to stop playing politics with the national security of the united states fundthewall nationalguard
# Twitter Name: Jimmy Panetta
# Actual party is Democratic and our classifier says Unknown.
# Here's our (cleaned) tweet: as congress considers disaster relief spending this year we must include funding for california fire relief listen to my remarks on the house floor here httpstcompkbk1m7s5
# Twitter Name: Adam Schiff
# Actual party is Democratic and our classifier says Unknown.
# Here's our (cleaned) tweet: proud to support oss helped vanquish some of most malevolent enemies our country— and free world— has ever faced httpstco8vyiaviftt

# %% [markdown]
# Now that we've looked at it some, let's score a bunch and see how we're doing.

# %%
parties = ['Republican', 'Democratic']
results = defaultdict(lambda: defaultdict(int))


for p in parties:
    for p1 in parties:
        results[p][p1] = 0

num_to_score = 10000
random.shuffle(tweet_data)

for idx, (twitter_name, party, processed_text) in enumerate(tweet_data):
    # Estimate the party affiliation using predict_party() function
    estimated_party_1 = predict_party(processed_text)

    results[party][estimated_party_1] += 1

    if idx > num_to_score:
        break

# %%
print(dict(results))
# Out:
# {'Republican': defaultdict(<class 'int'>, {'Republican': 353, 'Democratic': 53, 'Unknown': 3734}), 'Democratic': defaultdict(<class 'int'>, {'Republican': 332, 'Democratic': 183, 'Unknown': 5347})}

# %% [markdown]
# ### Reflections
#
# Based on what I have observed from the printing the results it appears the classifier is working as it was able to classify Republican, and Democratic. The only issue I noticed is that the unknown result is higher than both other party affiliations. This could be for a couple of reasons. 1. Not many users like to list their party affiliation in their text bios. Which is where the data was collected. 2. There could be other keywords that are not listed in the Keywords portion of the classifer that is just not detecting how most people identify their party affiliation through their twitter accounts.
